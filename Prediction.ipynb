# %% [markdown]
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="center">
#                 <font color="#21619" size=6px>
#                     <b>  Selling Price Prediction of Used Cars
#                     </b>
#                 </font>
#             </div>
#             <div align="center">
#                 <font color="#21619" size=4.5px>
#                     <b>
#                     </b>
#                 </font>
#             </div>
#             <div align="center">
#                 <font color="#21619" size=2px>
#                     <b>
#                     <br>
#                     </b>
#                 </font>
#             </div>
#             <div align="center">
#                 <font color="#21619" size=4px>
#                     <b>  Data analysis and Machine Learning Model Building
#                     </b>
#                 </font>
#             </div>
#          </td>
#     </tr>
# </table>

# %% [markdown]
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=4.8px>
#                     <b>  Author
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>
#
# * Roshankumar S
#
#
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=4px>
#                     <b>  Problem Statement
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>
#
# In the rapidly growing used car market, determining the appropriate selling price for a vehicle is a complex task influenced by various factors such as the car’s make, model, age, kilometers driven, condition, and other factors. Incorrect pricing can lead to financial losses for sellers and dissatisfaction for buyers. The goal of this project is to develop a predictive model that accurately estimates the selling price of used cars based on key attributes. By leveraging historical sales data and machine learning techniques, the model aims to assist sellers in setting competitive prices, thereby improving market efficiency and customer satisfaction.
#
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=4px>
#                     <b>  Objective
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>
#
# The objective of this project is to develop a machine learning model that accurately predicts the selling price of used cars based on a variety of features such as make, model, year of manufacture, kilometers driven, condition, and other relevant factors. The model will be trained on historical sales data and will be evaluated based on its predictive accuracy and generalizability. The ultimate goal is to provide a reliable tool for sellers to determine competitive pricing, aiding in quicker sales and maximizing profit margins, while also helping buyers make informed purchasing decisions.
#
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=4px>
#                     <b>  Regression Models
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>
#
# * **Linear Regression**
# * **Stochasitic Gradient Descent**
# * **Lasso**
# * **Ridge**
# * **Elastic Net Regressor**
# * **Random Forest Regressor**
# * **Ada Boost Regressor**
# * **Gradient Boost Regressor**
# * **XGB (Extreme Gradient Boost) Regressor**
#
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=4px>
#                     <b>  Data Description
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>
#
# The data set consists of complete educational details of students right from their schooling to MBA and previous work experience. Our main objective is to predict the Salary of the students based on the info available
#
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=4px>
#                     <b>  Data Dictionary
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>
#
# * **vehicle_id**                       -         Unique identifier for each vehicle
#
# * **year**                  -          Year of manufacture of the vehicle
#
# * **color**         -          Color of the vehicle
#
# * **make_name**            -          Brand or manufacturer of the vehicle (e.g., Toyota, Ford, BMW)
#
# * **model_name**        -          Specific model name of the vehicle (e.g., Corolla, Mustang, 3 Series)
#
# * **kilometer**            -          Total distance the vehicle has traveled, typically measured in kilometers
#
# * **grade**          -          Condition of the car, typically graded on a scale representing quality
#
# * **remarks**    -          Additional notes or comments regarding the vehicle, including any defects or special conditions
#
# * **net_book_value**    -          The book value of the vehicle after accounting for depreciation (purchase price minus depreciation)
#
# * **purchase_price**    -          The price at which the vehicle was originally purchased
#
# * **sale_price**    -          The final selling price of the vehicle
#
# * **purchase_date**    -          Date when the vehicle was purchased
#
# * **sale_date**    -          Date when the vehicle was sold
#
# * **min_bid_price**    -          The minimum acceptable bid price for the vehicle in an auction or sale
#
# * **expected_sale_price**    -          The price that the seller expects to receive for the vehicle
#
# * **fleet_status**    -         Current status of the vehicle in the fleet (e.g., 'SOLD', 'READY_FOR_SALE', 'TRANSFERRED', etc.)

# %% [markdown]
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=5px>
#                     <b>  Content
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>
#
# * ##### [1. Import Libraries](#libraries)
# * ##### [2. Data Understanding](#understanding)
# * ##### [3. Explorator Data Analysis](#eda)
#   * ##### [3.1 Univariate analysis of cateogrical features (Count Plots)](#categorical)
#   * ##### [3.2 Univariate analysis of numerical features (Box Plots and Histograms)](#numerical)
#   * ##### [3.3 Heat map of Correlation among numerical features](#correlation)
#   * ##### [3.4 Pairwise Scatterplot of numerical features](#scatter)
#   * ##### [3.5 Relation between Target and numerical features](#relation)
# * ##### [4. Data Preprocessing](#preprocessing)
#   * ##### [4.1 Treating outliers using capping method](#outlier)
#   * ##### [4.2 Transformation of numerical features using Yeo-Johnson method](#transformation)
#   * ##### [4.3 Encoding categorical features using Target encoding](#encoding)
#   * ##### [4.4 Splitting dataset into train set and test set](#split)
#   * ##### [4.5 Comparison of train set and test set](#testvstrain)
# * ##### [5. Model Building](#model)
# * ##### [6. Model Comparison](#comparison)
# * ##### [7. Statistical Summary of OLS model](#stats)
#   * ##### [7.1 Significant Features by analyzing P-values](#features)
#   * ##### [7.2 Checking Multicollinearity by analyzing VIF values](#vif)
# * ##### [8. Hyperparameter Tuning using Grid Search CV](#gridsearchcv)
#   * ##### [8.1 Tuning Ridge model](#ridge)
#   * ##### [8.2 Tuning Lasso model](#lasso)
#   * ##### [8.3 Tuning Elastic Net model](#elasticnet)
# * ##### [9. Feature selection using RFE and SFS](#rfesfs)
# * ##### [10. Feature Engineering by generation Polynomial features](#engineering)
# * ##### [11. Interpretation](#interpretation)
# * ##### [12. Conclusion](#conclusion)

# %% [markdown]
# <a id="libraries"><a>
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=5px>
#                     <b>  Import libraries
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# Import numpy for mathematical operations
import numpy as np

# Import pandas for performing operations on dataset
import pandas as pd

# Import matplotlib for visualization tools
import matplotlib.pyplot as plt

# Import seaborn for advanced visualization tools
import seaborn as sns

# Import stats module to perform statistical operations
from scipy import stats

# Import datetime for performing operations on date
from datetime import datetime

# Import Power Transformer for transformation
from sklearn.preprocessing import PowerTransformer

# Import train test split to split the dataset for training and testing
from sklearn.model_selection import train_test_split

# Import Linear Regression model
from sklearn.linear_model import LinearRegression

# Import Stochastic Gradient Descent model 
from sklearn.linear_model import SGDRegressor

# Import Ridge regularization model
from sklearn.linear_model import Ridge

# Import Lasso regularization model
from sklearn.linear_model import Lasso

# Import Elastic Net regressor model
from sklearn.linear_model import ElasticNet

# Import metrics for evaluation
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_percentage_error

# Import variance inflation factor
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Import Standard Scaler
from sklearn.preprocessing import StandardScaler

# Import statsmodels for model building
import statsmodels.stats.api as sms

# Import statsmodels for OLS model
import statsmodels.api as sm

# Import ensemble techniques 
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor 

# Import XGB regressor
from xgboost import XGBRegressor

# Import Recursieve Feature Selector
from sklearn.feature_selection import RFE,RFECV

# Import Sequential Feature Selector
from mlxtend.feature_selection import SequentialFeatureSelector as SFS

# Import Polynomial Features for feature engineering
from sklearn.preprocessing import PolynomialFeatures

# Import GridSearchCv for Hyperparameter tuning
from sklearn.model_selection import GridSearchCV

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

# %%
# Import the dataset
df=pd.read_csv("vehicle_details_new.csv")

# Display top 5 observations from the dataset
df.head()
# Out:
#    vehicle_id  year       color make_name        model_name  kilometer  \
# 0           1  2022  Black            BMW              520i    22278.0
# 1         100  2022  Blue              MG                 5    50585.0
# 2        1000  2022       White    NISSAN  Sunny SV 1.6 CVT        0.0
# 3        1001  2020       White    TOYOTA           Coaster   138578.0
# 4        1002  2021       White    TOYOTA           Corolla        0.0
#
#      grade            remarks  net_book_value  purchase_price  sale_price  \
# 0  GRADE_0         No Painted        82677.37        187000.0   157554.78
# 1  GRADE_0         No Painted        26002.35         38300.0    29340.00
# 2  SALVAGE  TP Received-18000        29933.00         45050.0    23300.00
# 3  SALVAGE  TP Received-53080       105329.00        181140.0    72350.44
# 4  SALVAGE  TP Received-32000        33107.00         58700.0    22800.00
#
#          purchase_date   sale_date  min_bid_price  expected_sale_price  \
# ...

# %%
# Filtering out data of cars which are currently in auction
df.drop(df[df["fleet_status"]=="ASSIGNED_TO_AUCTION"].index,inplace=True)

# Drop redundant columns
df.drop(columns=["expected_sale_price","min_bid_price","sale_date","fleet_status","remarks","vehicle_id"],inplace=True)

# Drop records where sale price value is missing
df.drop(df[df["sale_price"].isnull()].index,inplace=True)

# %%
# Calculate number of years since car has been manufactured
df["years since manufacture"] = df["year"].apply(lambda a : 2024-a)
df["purchase_date"] = pd.to_datetime(df["purchase_date"])
# Calculate number of months since car has been purchased
df["days since purchase"] = (datetime.now() -  df["purchase_date"]).dt.days   

# Drop the raw columns 
df.drop(columns=["year","purchase_date"],inplace=True)

# %%
df.head()
# Out:
#         color make_name        model_name  kilometer    grade  net_book_value  \
# 0  Black            BMW              520i    22278.0  GRADE_0        82677.37
# 1  Blue              MG                 5    50585.0  GRADE_0        26002.35
# 2       White    NISSAN  Sunny SV 1.6 CVT        0.0  SALVAGE        29933.00
# 3       White    TOYOTA           Coaster   138578.0  SALVAGE       105329.00
# 4       White    TOYOTA           Corolla        0.0  SALVAGE        33107.00
#
#    purchase_price  sale_price  years since manufacture  days since purchase
# 0        187000.0   157554.78                        2                 1035
# 1         38300.0    29340.00                        2                  952
# 2         45050.0    23300.00                        2                 1029
# 3        181140.0    72350.44                        4                 1456
# 4         58700.0    22800.00                        3                 1379

# %% [markdown]
# <a id="understanding"><a>
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=5px>
#                     <b>  Data Understanding
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# Display number of rows and columns
print("Number of rows: ", df.shape[0])
print("Number of columns: ", df.shape[1])
# Out:
# Number of rows:  6122
# Number of columns:  10

# %%
# Basic information of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6122 entries, 0 to 6515
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   color                    6122 non-null   object
#  1   make_name                6122 non-null   object
#  2   model_name               6122 non-null   object
#  3   kilometer                6122 non-null   float64
#  4   grade                    6122 non-null   object
#  5   net_book_value           6122 non-null   float64
#  6   purchase_price           6122 non-null   float64
#  7   sale_price               6122 non-null   float64
#  8   years since manufacture  6122 non-null   int64
#  9   days since purchase      6122 non-null   int64
# dtypes: float64(4), int64(2), object(4)
# memory usage: 526.1+ KB

# %%
# Descriptive statistics of numerical features
df.describe(include=np.number)
# Out:
#            kilometer  net_book_value  purchase_price     sale_price  \
# count    6122.000000     6122.000000     6122.000000    6122.000000
# mean    90475.641620    55222.878995    89835.956143   61104.941896
# std     62018.926553    38320.646665    58380.848841   40941.526500
# min         0.000000        1.000000    25442.000000    5777.390000
# 25%     49433.000000    28423.000000    45000.000000   31190.440000
# 50%     72932.000000    42819.000000    77400.000000   50300.000000
# 75%    118860.500000    71276.000000   116900.000000   76800.000000
# max    677049.000000   347079.000000   900000.000000  521739.130000
#
#        years since manufacture  days since purchase
# count              6122.000000          6122.000000
# mean                  2.889905          1192.642110
# std                   1.302467           428.824784
# min                   1.000000           320.000000
# 25%                   2.000000           839.000000
# ...

# %% [markdown]
# ### Replace color column with proper values

# %%
df["color"].unique()
# Out:
# array(['Black     ', 'Blue      ', 'White', 'Black', 'White     ',
#        'Silver', 'Blue', 'Grey', 'Grey      ', 'Red', 'Brown',
#        'Silver    ', 'Brown     ', 'Green', 'Golden', 'Yellow',
#        'Baige     ', 'Beige', 'Beige     ', 'Red       ', 'Orange',
#        'Gray', '37281', 'Silver\xa0\xa0\xa0\xa0',
#        'White\xa0\xa0\xa0\xa0\xa0', 'Golden    ', 'Lt. Golden'],
#       dtype=object)

# %%
df["color"].replace({'Black     ':'Black','Blue      ':'Blue','Grey      ':'Grey','White     ':'White','Silver    ':'Silver','Silver\xa0\xa0\xa0\xa0':'Silver','Beige     ':'Beige','Baige     ':'Beige','Red       ':'Red','Gray':'Grey','37281':'Red','White\xa0\xa0\xa0\xa0\xa0':'White','Golden    ':'Golden','Lt. Golden':'Golden', 'Brown     ':'Brown'},inplace=True)
df["color"].unique()
# Out:
# array(['Black', 'Blue', 'White', 'Silver', 'Grey', 'Red', 'Brown',
#        'Green', 'Golden', 'Yellow', 'Beige', 'Orange'], dtype=object)

# %% [markdown]
# ### Assign numbers based on grades

# %%
df["grade"].unique()
# Out:
# array(['GRADE_0', 'SALVAGE', 'GRADE_1', 'COMPLETE', 'GRADE_2', 'GRADE_3',
#        'GRADE_4', 'GRADE_5', 'GRADE_6'], dtype=object)

# %%
df["grade"].replace({'GRADE_0':8,'GRADE_1':7,'GRADE_2':6,'GRADE_3':5,'GRADE_4':4,'GRADE_5':3,'GRADE_6':2,'COMPLETE':1,'SALVAGE':0},inplace=True)
df["grade"].unique()
# Out:
# array([8, 0, 7, 1, 6, 5, 4, 3, 2])

# %%
# Descriptive statistics of categorical features
df.describe(include=object)
# Out:
#         color make_name        model_name
# count    6122      6122              6122
# unique     12        24               201
# top     White    TOYOTA  Fortuner VX1 4x4
# freq     3249      2360               666

# %% [markdown]
# <a id="eda"><a>
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=5px>
#                     <b>  Exploratory Data Analysis
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <a id="categorical"><a>
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=4px>
#                     <b>  Count plots for categorical data
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# Create axis for subplots
fig,subplots = plt.subplots(3,1,figsize=(20,20))

# Display count plot for all categorical columns
for column,axis in zip(df.select_dtypes(include=object),subplots.flatten()):
    sns.countplot(x=df[column],ax=axis,color="r")

# %% [markdown]
# ### Top 10 most sold colors

# %%
pd.DataFrame(df["color"].value_counts()[:10])
# Out:
#         count
# color
# White    3249
# Grey      816
# Silver    786
# Black     457
# Blue      276
# Brown     233
# Red       128
# Beige     107
# Golden     41
# Orange     13

# %% [markdown]
# ### Top 10 most sold brands

# %%
pd.DataFrame(df["make_name"].value_counts()[:10])
# Out:
#            count
# make_name
# TOYOTA      2360
# HYUNDAI     1121
# NISSAN       832
# FORD         585
# CHEVROLET    353
# MG           269
# CHERY        144
# KIA           95
# ISUZU         92
# RENAULT       61

# %% [markdown]
# ### Top 10 most sold models

# %%
pd.DataFrame(df["model_name"].value_counts()[:10])
# Out:
#                        count
# model_name
# Fortuner VX1 4x4         666
# Taurus Ambiente          397
# Accent                   349
# Elantra 1.6              314
# Yaris 1.3                285
# Sunny Classic SV 1.5L    269
# Tahoe LS 4x4             268
# 5                        268
# Corolla                  246
# Grand i10                205

# %%
# Display data about missing values
missing_data = pd.DataFrame(df.isnull().sum(),columns=["Absolute missing values"])
missing_data["Percentage of missing values"] = missing_data["Absolute missing values"]/len(df)*100
missing_data
# Out:
#                          Absolute missing values  Percentage of missing values
# color                                          0                           0.0
# make_name                                      0                           0.0
# model_name                                     0                           0.0
# kilometer                                      0                           0.0
# grade                                          0                           0.0
# net_book_value                                 0                           0.0
# purchase_price                                 0                           0.0
# sale_price                                     0                           0.0
# years since manufacture                        0                           0.0
# days since purchase                            0                           0.0

# %% [markdown]
# * We can see none of the columns have missing values
# * Hence we don't have to perform imputation

# %%
# Separate the dataset into numerical data and categorical data
df_num = df.select_dtypes(include=np.number)
df_cat = df.select_dtypes(include=object)

# %% [markdown]
# <a id="numerical"><a>
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=4px>
#                     <b>  Box Plots for numerical data
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# Create axis for subplots
fig,subplots = plt.subplots(4,2,figsize=(20,20))

# Display box plots for all numeric features
for column,axis in zip(df_num.columns,subplots.flatten()):
    sns.boxplot(y=df_num[column],ax=axis)

# %% [markdown]
# * We can observe few outliers present in some columns from the above plot.
# * We can treat those outliers using capping method.

# %% [markdown]
# ### Distribution for all numerical columns

# %%
# Create axis for subplots
fig,subplots = plt.subplots(4,2,figsize=(20,20))

# Display distribution plots for all numerical columns
for column,axis in zip(df_num.columns,subplots.flatten()):
    sns.distplot(df_num[column],ax=axis,color="r")

# %% [markdown]
# * We can see, every columns are skewed. Among them, few are highly skewed.
# * We can treat them by performing transformation.
# * Since some values are 0, we cannot use log / box-cox. Hence, we can use Yeo-Johnson transformation.

# %% [markdown]
# <a id="correlation"><a>
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=4px>
#                     <b>  Heat map of correlation
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# Display heat map for numerical features
plt.figure(figsize=(20,20))
sns.heatmap(df_num.corr(),annot=True)
plt.show()

# %% [markdown]
# <a id="scatter"><a>
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=4px>
#                     <b>  Pairwise Scatter plot for numerical features
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# Display pair plot for all combinations of numerical columns
sns.pairplot(df_num)
plt.show()

# %% [markdown]
# <a id="relation"><a>
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=4px>
#                     <b>  Scatter plot between Target and independent numerical features
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
X_num = df_num.drop(columns=["sale_price"],axis=True)
y = df["sale_price"]

# %%
# Plot scatter plot for each predictor attribute against the target
for i in X_num.columns:
    sns.scatterplot(x=X_num[i],y=y)
    plt.show()

# %% [markdown]
# * Purchase price and net book value are the columns which have high correlation with the target (selling price).

# %% [markdown]
# <a id="preprocessing"><a>
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=5px>
#                     <b>  Data Preprocessing
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <a id="outlier"><a>
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=4px>
#                     <b>  Outlier Treatment
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# List to store outliers for each numerical columns
outliers = []

# Iterate over each column and find outliers
for i in df_num.columns:
    Q1 = np.quantile(df_num[i],0.25) # First quantile
    Q3 = np.quantile(df_num[i],0.75) # Third quantile
    IQR = Q3-Q1 # Inter Quartile Range
    # Check condition for outliers
    outliers.append(df_num[i][ (df_num[i]<(Q1-(IQR*1.5))) | (df_num[i]>(Q3+(IQR*1.5))) ].unique())
    
# Display outlier values
pd.DataFrame({"Outliers":outliers},index=df_num.columns)
# Out:
#                                                                   Outliers
# kilometer                [261512.0, 225700.0, 266721.0, 248817.0, 25547...
# grade                                                                   []
# net_book_value           [208126.0, 157156.0, 290384.0, 304061.0, 18977...
# purchase_price           [228400.0, 447851.0, 900000.0, 580450.0, 31020...
# sale_price               [157554.78, 185000.0, 150200.0, 161100.0, 1537...
# years since manufacture                                            [8, 10]
# days since purchase       [2821, 2832, 2902, 2903, 3592, 2875, 2804, 3174]

# %% [markdown]
# ### Treat outliers using capping method

# %%
# for col in df_num.columns:
#     for row in df_num.index:
#         Q1 = np.quantile(df_num[col],0.25)
#         Q3 = np.quantile(df_num[col],0.75)
#         IQR = Q3-Q1
#         if df_num.loc[row,col]<(Q1-(IQR*1.5)):
#             df_num.loc[row,col] = Q1-(IQR*1.5)
#         if df_num.loc[row,col]>(Q3+(IQR*1.5)):
#             df_num.loc[row,col] = Q3+(IQR*1.5)

# %% [markdown]
# <a id="transformation"><a>
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=4px>
#                     <b>  Transformation using Yeo-Johnson method
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# Transform all numerical columns using Yeo-Johnson method
transformer = PowerTransformer()
df_transformed = pd.DataFrame(columns=df_num.columns,index=df_num.index)
for i in df_num.columns:
    df_transformed[i] = transformer.fit_transform(np.array(df_num[i]).reshape(-1,1))

# %%
# Skewness before transformation
df_num.skew()
# Out:
# kilometer                  2.164274
# grade                     -0.809532
# net_book_value             2.082524
# purchase_price             2.774778
# sale_price                 2.236634
# years since manufacture    0.801306
# days since purchase        0.827708
# dtype: float64

# %%
# Skewness after transformation
df_transformed.skew()
# Out:
# kilometer                  0.105092
# grade                     -0.557031
# net_book_value             0.168850
# purchase_price             0.057825
# sale_price                 0.014342
# years since manufacture    0.002465
# days since purchase        0.022184
# dtype: float64

# %%
# List of columns
columns = df_num.columns

# Number of columns
n_rows = len(columns)

# Create subplots
fig, axes = plt.subplots(nrows=n_rows, ncols=2, figsize=(10,5 * n_rows))

for i, col in enumerate(columns):
    sns.histplot(df_num[col], kde=True, ax=axes[i, 0]).set_title(f'Distribution of {col} in actual data')
    sns.histplot(df_transformed[col], kde=True, ax=axes[i, 1]).set_title(f'Distribution of {col} in transformed data')

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# * We can see that the skewness has been treated to a good standard.

# %%
# Store transformed data into actual dataframe
# df_num = df_transformed

# %% [markdown]
# <a id="encoding"><a>
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=4px>
#                     <b>  Encoding categorical columns using target encoding
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
sns.boxplot(df,y="sale_price",x="color")
plt.show()

# %% [markdown]
# * As we can observe almost for all colors selling prices are same, we can drop the `color` column

# %%
df["model_name"].nunique()
# Out:
# 201

# %% [markdown]
# * Since the number of categories is so high relative to the length of the dataset, we can drop the `model_name` column.

# %%
# df_cat.drop(columns=["color","model_name"],inplace=True)

# %% [markdown]
# ### Target encoding

# %%
encoder ={}
for col in df_cat.columns:
    encoder[col] = {}
    for category in df_cat[col].unique():
        encoder[col][category] = df_num[df_cat[col]==category]["sale_price"].mean()
    df_cat[col] = df_cat[col].map(encoder[col])

# %%
decoder = { col:{value:key for key,value in encoder[col].items()} for col in encoder.keys()}

# %% [markdown]
# <a id="split"><a>
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=4px>
#                     <b>  Train-Test Split
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# Extract independent numerical columns
X_num = df_num.drop("sale_price",axis=1)

# %%
# Define independent and target data
X = pd.concat([X_num,df_cat],axis=1)
y = df_num["sale_price"]

# %%
X.describe()
# Out:
#            kilometer        grade  net_book_value  purchase_price  \
# count    6122.000000  6122.000000     6122.000000     6122.000000
# mean    90475.641620     5.646031    55222.878995    89835.956143
# std     62018.926553     2.645472    38320.646665    58380.848841
# min         0.000000     0.000000        1.000000    25442.000000
# 25%     49433.000000     4.000000    28423.000000    45000.000000
# 50%     72932.000000     7.000000    42819.000000    77400.000000
# 75%    118860.500000     8.000000    71276.000000   116900.000000
# max    677049.000000     8.000000   347079.000000   900000.000000
#
#        years since manufacture  days since purchase          color  \
# count              6122.000000          6122.000000    6122.000000
# mean                  2.889905          1192.642110   61104.941896
# std                   1.302467           428.824784   14351.111475
# min                   1.000000           320.000000   24650.157561
# ...

# %%
# Split dataset using train test split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=100)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (4285, 9)
# (1837, 9)
# (4285,)
# (1837,)

# %% [markdown]
# <a id="testvstrain"><a>
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=4px>
#                     <b>  Check if train set and test set are representation of overall dataset
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
plt.figure(figsize=(15,6))

plt.subplot(121)
sns.distplot(y_train,color="red")

plt.subplot(122)
sns.distplot(y_test,color="green")

plt.show()

# %% [markdown]
# * Since test data and train data are similar, we can conclude that both train and test represents the overall data.

# %% [markdown]
# <a id="model"><a>
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=5px>
#                     <b>  Model Building
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### Initialize regression models and train them

# %%
linear = LinearRegression().fit(X_train,y_train)
stochastic = SGDRegressor(random_state=100).fit(X_train,y_train)
ridge = Ridge(alpha=5,random_state=100).fit(X_train,y_train)
lasso = Lasso(alpha=7,random_state=100).fit(X_train,y_train)
elasticnet = ElasticNet(alpha=2,l1_ratio=0.01,random_state=100).fit(X_train,y_train)
rfregressor = RandomForestRegressor(random_state=100,n_estimators=100).fit(X_train,y_train)
gbregressor = GradientBoostingRegressor(random_state=100,n_estimators=100).fit(X_train,y_train)
abregressor = AdaBoostRegressor(random_state=100,n_estimators=100).fit(X_train,y_train)
xgbregressor = XGBRegressor(random_state=100,n_estimators=100).fit(X_train,y_train)

# %% [markdown]
# <a id="comparison"><a>
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=5px>
#                     <b>  Models Comparison
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### Predict train and test data to find metric

# %%
X_train
# Out:
#       kilometer  grade  net_book_value  purchase_price  \
# 1944   150467.0      4        40799.00         92400.0
# 3804   121471.0      1        42428.00         58050.0
# 2301    47013.0      7        35865.00         45550.0
# 531     40136.0      6       101155.00        174003.0
# 1438    62038.0      7        32968.62         43050.0
# ...         ...    ...             ...             ...
# 6420    76900.0      6        39838.00         73500.0
# 80      56037.0      8        16305.00         44550.0
# 4146   115845.0      8        87126.00        126350.0
# 6349   232252.0      6        18949.00         54600.0
# 5926   128472.0      8        57291.00         97515.0
#
#       years since manufacture  days since purchase          color  \
# 1944                        5                 2153   60953.690231
# 3804                        2                  923   61923.898860
# 2301                        1                  733   40199.249898
# ...

# %%
models = [linear,stochastic,ridge,lasso,elasticnet,rfregressor,gbregressor,abregressor,xgbregressor]
performance = pd.DataFrame({"Model":models})
performance["R-square (train)"] = performance["Model"].apply(lambda model : r2_score(y_train,model.predict(X_train)))
performance["R-square (test)"] = performance["Model"].apply(lambda model : r2_score(y_test,model.predict(X_test)))
performance["RMSE (train)"] = performance["Model"].apply(lambda model : mean_squared_error(y_train,model.predict(X_train))**0.5)
performance["RMSE (test)"] = performance["Model"].apply(lambda model : mean_squared_error(y_test,model.predict(X_test))**0.5)
performance["MAPE (train)"] = performance["Model"].apply(lambda model : mean_absolute_percentage_error(y_train,model.predict(X_train))**0.5)
performance["MAPE (test)"] = performance["Model"].apply(lambda model : mean_absolute_percentage_error(y_test,model.predict(X_test))**0.5)

# %%
# Round of the metrics to 4 decimal places
performance["R-square (train)"] = performance["R-square (train)"].apply(lambda a : str(round(a,4)))
performance["R-square (test)"] = performance["R-square (test)"].apply(lambda a : str(round(a,4)))
performance["RMSE (train)"] = performance["RMSE (train)"].apply(lambda a : str(round(a,4)))
performance["RMSE (test)"] = performance["RMSE (test)"].apply(lambda a : str(round(a,4)))
performance["MAPE (train)"] = performance["MAPE (train)"].apply(lambda a : str(round(a,4)))
performance["MAPE (test)"] = performance["MAPE (test)"].apply(lambda a : str(round(a,4)))

# %%
# Display performance statistics for all models
performance
# Out:
#                                                Model         R-square (train)  \
# 0                                 LinearRegression()                   0.9678
# 1                     SGDRegressor(random_state=100)  -1.4871103626822675e+29
# 2                   Ridge(alpha=5, random_state=100)                   0.9678
# 3                   Lasso(alpha=7, random_state=100)                   0.9678
# 4  ElasticNet(alpha=2, l1_ratio=0.01, random_stat...                   0.9673
# 5  (DecisionTreeRegressor(max_features=1.0, rando...                   0.9978
# 6  ([DecisionTreeRegressor(criterion='friedman_ms...                   0.9833
# 7  (DecisionTreeRegressor(max_depth=3, random_sta...                    0.951
# 8  XGBRegressor(base_score=None, booster=None, ca...                   0.9975
#
#            R-square (test)            RMSE (train)             RMSE (test)  \
# 0                   0.9651               7293.9507               7783.6198
# ...

# %% [markdown]
# * We can clearly see that XGB regressor model has the best performance in test data.
# * It has good R-square and RMSE metric value.

# %% [markdown]
# ### Model Accuracy in terms of percentage

# %%
results = pd.DataFrame({"Predicted":xgbregressor.predict(X_test),"Actual":y_test})
results["Percentage difference"] = results[["Predicted","Actual"]].apply(lambda a : np.abs(a[0]-a[1])/a[0]*100,axis=1)
print("Accuracy of the model: ",round(100 - results["Percentage difference"].mean(),2),"%")
# Out:
# Accuracy of the model:  93.53 %

# %%
pd.DataFrame({"Predicted":xgbregressor.predict(X_test),"Actual":y_test})
# Out:
#           Predicted     Actual
# 2822   81734.203125   79500.00
# 4807   25300.119141   23494.78
# 3091   24617.330078   35052.17
# 2711   68930.804688   65160.00
# 1071   76686.343750   72000.00
# ...             ...        ...
# 4073   26263.906250   27000.00
# 598    26390.351562   27188.69
# 878   131159.859375  134781.74
# 1496   69116.437500   69565.22
# 5347   53113.164062   58190.44
#
# [1837 rows x 2 columns]

# %% [markdown]
# <a id="stats"><a>
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=5px>
#                     <b>  Statistical Summary of OLS model
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
X_constant = sm.add_constant(X_train)
linear_OLS = sm.OLS(y_train,X_constant).fit()

# %%
linear_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             sale_price   R-squared:                       0.968
# Model:                            OLS   Adj. R-squared:                  0.968
# Method:                 Least Squares   F-statistic:                 1.427e+04
# Date:                Sun, 01 Sep 2024   Prob (F-statistic):               0.00
# Time:                        14:48:57   Log-Likelihood:                -44194.
# No. Observations:                4285   AIC:                         8.841e+04
# Df Residuals:                    4275   BIC:                         8.847e+04
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# * Adjusted R-square considers number of columns into account whereas R-square doesnot consider it for evaluation.
# * Adjusted R-square is used to check if there are any garbage features used for prediction.
# * Since there is no much difference in R-square and adjusted R-square in above model, we can conclude that all features are significant in prediction,

# %% [markdown]
# <a id="features"><a>
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=4px>
#                     <b>  Insignificant Features
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### Check insignificant features which have P-value less than 0.05

# %%
X.columns[linear_OLS.pvalues[1:]>0.05]
# Out:
# Index(['years since manufacture'], dtype='object')

# %% [markdown]
# <a id="gridsearchcv"><a>
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=5px>
#                     <b>  Hyperparameter tuning using GridSearchCV
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <a id="ridge"><a>
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=4px>
#                     <b>  Tuning Ridge model
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
tune_params = {"alpha":np.arange(0,10,0.1)}
ridge = Ridge()
ridge_params = GridSearchCV(ridge,tune_params,scoring="r2",cv=10).fit(X_train,y_train)
best_params = ridge_params.best_params_

# %%
ridge = Ridge(**best_params).fit(X_train,y_train)
r2_score(y_test,ridge.predict(X_test))
# Out:
# 0.965057380387312

# %% [markdown]
# <a id="lasso"><a>
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=4px>
#                     <b>  Tuning Lasso model
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
tune_params = {"alpha":np.arange(0,10,0.1)}
lasso = Lasso()
lasso_params = GridSearchCV(lasso,tune_params,scoring="r2",cv=10).fit(X_train,y_train)
best_params = lasso_params.best_params_

# %%
lasso = Lasso(**best_params).fit(X_train,y_train)
r2_score(y_test,lasso.predict(X_test))
# Out:
# 0.9650578876834861

# %% [markdown]
# <a id="elasticnet"><a>
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=4px>
#                     <b>  Tuning Elastic Net model
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
tune_params = {"alpha":np.arange(0,10,0.1),"l1_ratio":[0.1,0.01,0.001,0.0001]}
elastic = ElasticNet()
elastic_params = GridSearchCV(elastic,tune_params,scoring="r2",cv=10).fit(X_train,y_train)
best_params = elastic_params.best_params_

# %%
elastic = ElasticNet(**best_params).fit(X_train,y_train)
r2_score(y_test,elastic.predict(X_test))
# Out:
# 0.9650384444615837

# %% [markdown]
# <a id="rfesfs"><a>
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=5px>
#                     <b>  Feature selection using RFE and SFS
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
xgbregressor = XGBRegressor()
rfecv = RFECV(estimator=xgbregressor,cv=10,scoring="r2").fit(X=X_train,y=y_train)
X.columns[rfecv.ranking_==1]
# Out:
# Index(['kilometer', 'grade', 'net_book_value', 'purchase_price',
#        'years since manufacture', 'model_name'],
#       dtype='object')

# %%
X = X[X.columns[rfecv.ranking_==1]]
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=100)

# %%
xgbregressor = XGBRegressor().fit(X_train,y_train)
r2_score(y_test,xgbregressor.predict(X_test))
# Out:
# 0.9699124943599675

# %% [markdown]
# * After feature selection, the accuracy got reduced. Hence, we can consider all features.

# %% [markdown]
# <a id="engineering"><a>
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=5px>
#                     <b>  Feature Engineering by generating Polynomial Features of degree 2
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
polynomial = PolynomialFeatures()

# %%
X_featured = polynomial.fit_transform(X)

# %%
X_train,X_test,y_train,y_test = train_test_split(X_featured,y,test_size=0.3,random_state=100)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (4285, 28)
# (1837, 28)
# (4285,)
# (1837,)

# %%
model = xgbregressor.fit(X_train,y_train)
r2_score(y_test,model.predict(X_test))
# Out:
# 0.9686554882109789

# %% [markdown]
# ### Model Accuracy in terms of percentage

# %%
results = pd.DataFrame({"Predicted":model.predict(X_test),"Actual":y_test})
results["Percentage difference"] = results[["Predicted","Actual"]].apply(lambda a : np.abs(a[0]-a[1])/a[0]*100,axis=1)
print("Accuracy:",round(100-results["Percentage difference"].mean(),2),"%")
# Out:
# Accuracy: 93.44 %

# %% [markdown]
# * After doing feature engineerin the accuracy got reduced. Hence, we can ignore this step.

# %% [markdown]
# <a id="interpretation"></a>
#
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=5px>
#                     <b>Interpretation</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>
#
# In this project, a journey was undertaken to predict car price based on a historic car sales. A systematic approach was followed, beginning with exploratory data analysis (EDA), data preprocessing, model building, hyperparameter tuning, and feature engineering. Here are the key takeaways and conclusions from the project:
#
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=4px>
#                     <b>Exploratory Data Analysis (EDA)</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>
#
# A deep understanding of the dataset was gained through EDA. This involved creating count plots for categorical variables, histograms, and boxplots for numerical variables, heatmaps to visualize correlations, and pairwise scatter plots to identify potential relationships between features.
#
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=4px>
#                     <b>Data Preprocessing</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>
#
# Data preprocessing was deemed crucial for model success. Outliers were found which can be treated using capping method.
#
# The Yeo-Johnson transformation can be applied to handle skewness in numerical features.
#
# Target encoding was utilized to effectively encode categorical variables.
#
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=4px>
#                     <b>Model Building and Comparison</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>
#
# Various regression models were experimented with, including Linear Regression, Lasso, Ridge, Stochastic Gradient Descent (SGD), ElasticNet and ensemble techniques like Random Forest, Ada Boost, Gradient Boost and Xtreme Gradient Boost.
#
# The best-performing model, XGB Regressor, emerged, exhibiting the highest accuracy in predicting car prices.
#
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=4px>
#                     <b>Hyperparameter Tuning</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>
#
# To further optimize the XGB regressor model, hyperparameter tuning was performed using GridSearchCV, fine-tuning the regularization strength (alpha). But since the accuracy hasn't improved the initial model is retained as it is.
#
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=4px>
#                     <b>Feature Selection</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>
#
# Recursive Feature Elimination (RFE) technique was employed to identify and select the most informative features.
#
# These feature selection method hasn't improved. Hence all the features are considered for model building
#
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=4px>
#                     <b>Feature Engineering</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>
#
# Feature engineering was explored by generating polynomial features of degree 2. Interestingly, this approach was associated with an unexpected outcome, as the addition of polynomial features led to a decrease in model performance.
#
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=4px>
#                     <b>Project Insights</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>
#
# The XGB Regression model, with optimized hyperparameters, was found to be the most suitable for predicting salary based on student details.
#
# While feature selection techniques contributed to improved model efficiency, it was observed that the addition of polynomial features did not provide a significant benefit in this context. This highlighted the importance of careful feature engineering and evaluation.
#
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=4px>
#                     <b>Future Directions</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>
#
# Future iterations of this project could consider the potential incorporation of external data sources to further enhance model performance.

# %% [markdown]
# <a id="conclusion"><a>
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=5px>
#                     <b>  Conclusion
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>
#
#    In conclusion, valuable insights into car price prediction based on historical sales data were gained through this project. The XGB Regression model, along with data preprocessing, demonstrated promising results. It forms a solid foundation for further exploration and improvement in the field of car price prediction.
